# %%
import sys 
sys.path.append('..')
import pandas as pd
from IPython.display import display
from modules.tools import print_df, print_dfs
from modules.data import Data, Vector, rep
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import word_tokenize, TreebankWordTokenizer, RegexpTokenizer

# %%
data = Data()

# %%
print data.path
print_df(data.questions)
print_df(data.reviews)
# Out:
# ['../data/qa_Beauty.json.gz', '../data/reviews_Beauty_5.json.gz']
#   questionType        asin    answerTime  \
# 0       yes/no  602260074X   10 days ago
# 1       yes/no  602260074X   Mar 3, 2015
# 2       yes/no  602260074X  Dec 30, 2014
# 3   open-ended  602260074X  Jul 13, 2014
# 4       yes/no  602260074X  May 21, 2014
#
#                                             question answerType  \
# 0           can you fit make up brushes in the trays          Y
# 1                     Can you move all the dividers?          ?
# 2                 is the surface in side the smooth?          Y
# 3           How deep do the extending trays measure?        NaN
# 4  Can bottles of nail polish stand upright in th...          ?
#
#                                               answer      unixTime
# 0  yes it comes with adjustable dividers, you can...           NaN
# 1       yes,all the provided dividers are adjustable  1.425370e+09
# ...

# %%
data.questions.shape
# Out:
# (42422, 7)

# %%
data.reviews.shape
# Out:
# (198502, 9)

# %%
data.questions.questionType.value_counts()
# Out:
# open-ended    24331
# yes/no        18091
# Name: questionType, dtype: int64

# %%
# data.questions.to_csv('questions.csv')

# %%
# data.reviews.to_csv('reviews.csv')

# %%
# data.questions.asin.value_counts().to_csv('product_counts.csv')

# %%
data.questions.asin.value_counts().shape
# Out:
# (5906,)

# %%
data.questions.asin.value_counts().describe()
# Out:
# count    5906.000000
# mean        7.182865
# std         2.661562
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        10.000000
# max        10.000000
# Name: asin, dtype: float64

# %%
data.questions.asin.value_counts().value_counts()
# Out:
# 10    2157
# 4      688
# 3      673
# 5      607
# 6      523
# 7      425
# 9      414
# 8      396
# 2       16
# 1        7
# Name: asin, dtype: int64

# %%
data.questions
# Out:
#       questionType        asin    answerTime  \
# 0           yes/no  602260074X   10 days ago
# 1           yes/no  602260074X   Mar 3, 2015
# 2           yes/no  602260074X  Dec 30, 2014
# 3       open-ended  602260074X  Jul 13, 2014
# 4           yes/no  602260074X  May 21, 2014
# 5       open-ended  602260074X  Feb 25, 2014
# 6       open-ended  602260074X   Dec 3, 2013
# 7       open-ended  602260074X  Jul 23, 2013
# 8       open-ended  7800558258   18 days ago
# 9       open-ended  7800558258  Feb 28, 2015
# 10      open-ended  7800558258  May 28, 2014
# 11          yes/no  7800558258  Jan 30, 2014
# 12          yes/no  7800558258   Nov 6, 2013
# 13      open-ended  9788071813  Jun 10, 2014
# 14      open-ended  9788071813  Apr 23, 2014
# 15          yes/no  9788071813  Apr 23, 2014
# 16      open-ended  B00004TUBL  Aug 15, 2013
# 17      open-ended  B00004TUBL   Dec 6, 2014
# 18          yes/no  B00004TUBL  Jun 12, 2014
# 19      open-ended  B00004TUBL  Oct 10, 2014
# ...

# %%
data.questions.question
# Out:
# 0                 can you fit make up brushes in the trays
# 1                           Can you move all the dividers?
# 2                       is the surface in side the smooth?
# 3                 How deep do the extending trays measure?
# 4        Can bottles of nail polish stand upright in th...
# 5                                     what are the Weight?
# 6                                 What are the dimensions?
# 7        What are the tray size dimensions please? Heig...
# 8        how can I get a product manual copy or electro...
# 9        I have used the PE-901P. How does the D-901P c...
# 10       goodnight crompre an east electrocautery, and ...
# 11                       Does it work for pedal? Thank you
# 12       does it come with everything shown in the pict...
# 13       how i know if the perfume or eau de toylette f...
# 14       Is this product in an unopened box? like the o...
# 15                         Is it in an original packaging?
# ...

# %%
# for i, s in enumerate(df):
#     if '0120414' in s:
#         print i, s

# %%
data.questions.loc[25190][['question', 'answer']]
# Out:
# question    I want to know coding bottom of the bottle, it...
# answer      Hello, The number on the bottom of the bottle ...
# Name: 25190, dtype: object

# %%
def rep(s):
    parse_dict = {
#     " *_+": " __underscore__",
    " *\d+": " __number__"
    }
    for k, v in parse_dict.items():
        s = re.sub(" *\d+", " #### ", s)
    return s

# %%
import re
s= " 1234 lkjslkj 1234/2343"
s = re.sub(" *\d+", " #### ", s)
s
# Out:
# ' ####  lkjslkj #### / #### '

# %%
df_num = data.questions.question.apply(rep)

# %%
df_num
# Out:
# 0                 can you fit make up brushes in the trays
# 1                           Can you move all the dividers?
# 2                       is the surface in side the smooth?
# 3                 How deep do the extending trays measure?
# 4        Can bottles of nail polish stand upright in th...
# 5                                     what are the Weight?
# 6                                 What are the dimensions?
# 7        What are the tray size dimensions please? Heig...
# 8        how can I get a product manual copy or electro...
# 9        I have used the PE- #### P. How does the D- ##...
# 10       goodnight crompre an east electrocautery, and ...
# 11                       Does it work for pedal? Thank you
# 12       does it come with everything shown in the pict...
# 13       how i know if the perfume or eau de toylette f...
# 14       Is this product in an unopened box? like the o...
# 15                         Is it in an original packaging?
# ...

# %%
vector = Vector(df_num, max_df=0.5, min_df=2, n=2)
vector.vect
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=0.5, max_features=None, min_df=2,
#         ngram_range=(1, 2), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=<bound method RegexpTokenizer.tokenize of RegexpTokenizer(pattern='\\w+', gaps=False, discard_empty=True, flags=56)>,
#         vocabulary=None)

# %%
len(vector.vect.get_feature_names())
# Out:
# 30589
